# %% [markdown]
# # Modeling
#
# Train and evaluate logistic regression on survey data.

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

df = pd.read_csv('../data/cleaned/responses_cleaned.csv')
df.head()
