# %% [markdown]
# # Exploratory Data Analysis
#
# Initial look at participant demographics and survey responses.

# %%
import pandas as pd

participants = pd.read_csv('../data/raw/participants.csv')
participants.head()
